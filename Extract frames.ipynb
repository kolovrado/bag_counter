# %%
import cv2
from PIL import Image

# %%
source_path = 'video_2024-06-03_15-38-55.mp4'

# %%
vidcap = cv2.VideoCapture(source_path)
fps = vidcap.get(cv2.CAP_PROP_FPS)
frameSize = (int(vidcap.get(cv2.CAP_PROP_FRAME_WIDTH)),
    int(vidcap.get(cv2.CAP_PROP_FRAME_HEIGHT)))

# %%
for i in range(1500):
    success, reference_frame = vidcap.read()

# %%
Image.fromarray(reference_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=640x352>

# %%
cv2.imshow("FRAME", reference_frame)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x3a54e60) is not the object's thread (0x4ac03e0).
# Cannot move to target thread (0x3a54e60)
#
# QObject::moveToThread: Current thread (0x3a54e60) is not the object's thread (0x4ac03e0).
# Cannot move to target thread (0x3a54e60)
#
# QObject::moveToThread: Current thread (0x3a54e60) is not the object's thread (0x4ac03e0).
# Cannot move to target thread (0x3a54e60)
#
# QObject::moveToThread: Current thread (0x3a54e60) is not the object's thread (0x4ac03e0).
# Cannot move to target thread (0x3a54e60)
#
# QObject::moveToThread: Current thread (0x3a54e60) is not the object's thread (0x4ac03e0).
# Cannot move to target thread (0x3a54e60)
#
# QObject::moveToThread: Current thread (0x3a54e60) is not the object's thread (0x4ac03e0).
# Cannot move to target thread (0x3a54e60)
#
# QObject::moveToThread: Current thread (0x3a54e60) is not the object's thread (0x4ac03e0).
# Cannot move to target thread (0x3a54e60)
#
# ...

# %%
for j in range(1500, 3200):
    
    success, reference_frame = vidcap.read()
    if success:
        if not j%6:
            cv2.imwrite(f"bags/{'0'*(5-len(str(j//100)))}{j//100}.png", reference_frame) 
    else:
        break

# %%
# Out:
# '0'

# %%
results = model(reference_frame,conf = 0.1, save=True)
# Out:
# 0: 352x640 1 Clothing, 1 Person, 1 Vehicle, 7.1ms
# Speed: 23.2ms preprocess, 7.1ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to runs/detect/predict3

# %%
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    print(boxes, probs)
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([381., 115., 567.], device='cuda:0')
# conf: tensor([0.4737, 0.2365, 0.1318], device='cuda:0')
# data: tensor([[8.6739e+01, 9.9147e+01, 1.4851e+02, 2.4033e+02, 4.7368e-01, 3.8100e+02],
#         [8.7107e+01, 1.1388e+02, 1.4619e+02, 2.3172e+02, 2.3647e-01, 1.1500e+02],
#         [0.0000e+00, 0.0000e+00, 5.4236e+02, 3.5171e+02, 1.3183e-01, 5.6700e+02]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (352, 640)
# shape: torch.Size([3, 6])
# xywh: tensor([[117.6233, 169.7383,  61.7678, 141.1826],
#         [116.6466, 172.7989,  59.0786, 117.8391],
#         [271.1794, 175.8551, 542.3589, 351.7103]], device='cuda:0')
# xywhn: tensor([[0.1838, 0.4822, 0.0965, 0.4011],
#         [0.1823, 0.4909, 0.0923, 0.3348],
#         [0.4237, 0.4996, 0.8474, 0.9992]], device='cuda:0')
# xyxy: tensor([[ 86.7393,  99.1470, 148.5072, 240.3297],
#         [ 87.1073, 113.8794, 146.1859, 231.7184],
# ...

# %%
results[0].names[381]
# Out:
# 'Person'

# %%
results
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...
